# %%
# 1️⃣ Import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical

# %%
# 2️⃣ Load CSV files
train = pd.read_csv("datasets/mnist_train.csv")
test  = pd.read_csv("datasets/mnist_test.csv")

# %%
# 3. Prepare data
X_train = train.drop('label', axis=1).to_numpy().astype('float32') / 255.0
X_test  = test.drop('label', axis=1).to_numpy().astype('float32') / 255.0
y_train = to_categorical(train['label'].to_numpy(), 10)
y_test  = to_categorical(test['label'].to_numpy(), 10)

print("Train shape:", X_train.shape, "Test shape:", X_test.shape)
# Out:
# Train shape: (60000, 784) Test shape: (10000, 784)

# %%
# 4. Build a simple but strong MLP
model = Sequential([
    Input(shape=(784,)),
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(10, activation='softmax')
])
model.compile(optimizer=Adam(learning_rate=1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_7 (Dense)                      │ (None, 512)                 │         401,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 512)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 256)                 │         131,328 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 10)                  │           2,570 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 535,818 (2.04 MB)
#  Trainable params: 535,818 (2.04 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 5️⃣ Train model (11 epochs)
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=11, batch_size=128,verbose=2)
# Out:
# Epoch 1/11
# 469/469 - 5s - 10ms/step - accuracy: 0.9156 - loss: 0.2784 - val_accuracy: 0.9657 - val_loss: 0.1103
# Epoch 2/11
# 469/469 - 3s - 6ms/step - accuracy: 0.9634 - loss: 0.1211 - val_accuracy: 0.9716 - val_loss: 0.0893
# Epoch 3/11
# 469/469 - 3s - 7ms/step - accuracy: 0.9730 - loss: 0.0877 - val_accuracy: 0.9768 - val_loss: 0.0721
# Epoch 4/11
# 469/469 - 3s - 7ms/step - accuracy: 0.9779 - loss: 0.0690 - val_accuracy: 0.9790 - val_loss: 0.0695
# Epoch 5/11
# 469/469 - 3s - 6ms/step - accuracy: 0.9822 - loss: 0.0570 - val_accuracy: 0.9809 - val_loss: 0.0633
# Epoch 6/11
# 469/469 - 3s - 6ms/step - accuracy: 0.9837 - loss: 0.0498 - val_accuracy: 0.9795 - val_loss: 0.0663
# Epoch 7/11
# 469/469 - 3s - 7ms/step - accuracy: 0.9856 - loss: 0.0439 - val_accuracy: 0.9821 - val_loss: 0.0632
# Epoch 8/11
# 469/469 - 3s - 7ms/step - accuracy: 0.9862 - loss: 0.0403 - val_accuracy: 0.9806 - val_loss: 0.0621
# Epoch 9/11
# 469/469 - 3s - 6ms/step - accuracy: 0.9886 - loss: 0.0356 - val_accuracy: 0.9829 - val_loss: 0.0595
# Epoch 10/11
# 469/469 - 3s - 6ms/step - accuracy: 0.9887 - loss: 0.0341 - val_accuracy: 0.9826 - val_loss: 0.0604
# Epoch 11/11
# 469/469 - 3s - 6ms/step - accuracy: 0.9896 - loss: 0.0312 - val_accuracy: 0.9827 - val_loss: 0.0614

# %%
# 6️⃣ Evaluate model
loss, acc = model.evaluate(X_test, y_test)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {acc*100:.2f}%")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9793 - loss: 0.0693
# Test Loss: 0.0614
# Test Accuracy: 98.27%

# %%
# 7️⃣ Classification report
y_pred = np.argmax(model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_pred))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      0.99      0.99      1135
#            2       0.98      0.98      0.98      1032
#            3       0.97      0.99      0.98      1010
#            4       0.97      0.99      0.98       982
#            5       0.99      0.98      0.98       892
#            6       0.99      0.99      0.99       958
#            7       0.98      0.98      0.98      1028
#            8       0.99      0.97      0.98       974
#            9       0.98      0.96      0.97      1009
#
#     accuracy                           0.98     10000
#    macro avg       0.98      0.98      0.98     10000
# weighted avg       0.98      0.98      0.98     10000

# %%
# 8️⃣ Plot training accuracy & loss
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(history.history['accuracy'], label='train')
plt.plot(history.history['val_accuracy'], label='val')
plt.title("Accuracy"); plt.legend()

plt.subplot(1,2,2)
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.title("Loss"); plt.legend()
plt.show()
