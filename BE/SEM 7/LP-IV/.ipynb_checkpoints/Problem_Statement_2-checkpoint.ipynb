# %%
# Cell 1 — imports
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dense
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
# Cell 2 — load & preprocess
train = pd.read_csv("datasets/mnist_train.csv")
test  = pd.read_csv("datasets/mnist_test.csv")
X_train = train.drop('label', axis=1).to_numpy().astype('float32')/255.0
X_test  = test.drop('label', axis=1).to_numpy().astype('float32')/255.0
y_train = to_categorical(train['label'].to_numpy(), 10)
y_test  = to_categorical(test['label'].to_numpy(), 10)
X_train = X_train.reshape(-1,28,28,1); X_test = X_test.reshape(-1,28,28,1)

# %%
# Cell 3 — model (very simple)
model = Sequential([
    Input((28,28,1)),
    Conv2D(32,3, activation='relu'),
    MaxPool2D(),
    Conv2D(64,3, activation='relu'),
    MaxPool2D(),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')
])
model.compile(optimizer=Adam(1e-3), loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ...

# %%
# Cell 4 — train (11 epochs)
history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=11, batch_size=128, verbose=2)
# Out:
# Epoch 1/11
# 469/469 - 10s - 21ms/step - accuracy: 0.9354 - loss: 0.2190 - val_accuracy: 0.9788 - val_loss: 0.0673
# Epoch 2/11
# 469/469 - 8s - 16ms/step - accuracy: 0.9828 - loss: 0.0554 - val_accuracy: 0.9866 - val_loss: 0.0471
# Epoch 3/11
# 469/469 - 7s - 16ms/step - accuracy: 0.9880 - loss: 0.0389 - val_accuracy: 0.9891 - val_loss: 0.0321
# Epoch 4/11
# 469/469 - 8s - 16ms/step - accuracy: 0.9907 - loss: 0.0293 - val_accuracy: 0.9927 - val_loss: 0.0249
# Epoch 5/11
# 469/469 - 9s - 19ms/step - accuracy: 0.9933 - loss: 0.0219 - val_accuracy: 0.9910 - val_loss: 0.0298
# Epoch 6/11
# 469/469 - 9s - 18ms/step - accuracy: 0.9945 - loss: 0.0176 - val_accuracy: 0.9905 - val_loss: 0.0321
# Epoch 7/11
# 469/469 - 8s - 17ms/step - accuracy: 0.9955 - loss: 0.0145 - val_accuracy: 0.9885 - val_loss: 0.0345
# Epoch 8/11
# 469/469 - 8s - 16ms/step - accuracy: 0.9958 - loss: 0.0122 - val_accuracy: 0.9882 - val_loss: 0.0413
# Epoch 9/11
# ...

# %%
# Cell 5 — evaluate
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {loss:.4f}  Test Accuracy: {acc*100:.2f}%")
# Out:
# Test Loss: 0.0357  Test Accuracy: 98.96%

# %%
y_pred = np.argmax(model.predict(X_test), axis=1)
y_true = np.argmax(y_test, axis=1)
print(classification_report(y_true, y_pred))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       980
#            1       0.99      1.00      0.99      1135
#            2       0.99      0.99      0.99      1032
#            3       0.99      0.99      0.99      1010
#            4       0.99      0.98      0.99       982
#            5       0.99      0.99      0.99       892
#            6       0.99      0.99      0.99       958
#            7       0.98      0.99      0.99      1028
#            8       0.99      0.99      0.99       974
#            9       0.99      0.98      0.98      1009
#
#     accuracy                           0.99     10000
#    macro avg       0.99      0.99      0.99     10000
# weighted avg       0.99      0.99      0.99     10000

# %%
# Cell 6 — quick plot
plt.style.use('ggplot')
e = range(len(history.history['loss']))
plt.plot(e, history.history['accuracy'], label='train_acc')
plt.plot(e, history.history['val_accuracy'], label='val_acc')
plt.plot(e, history.history['loss'], label='train_loss')
plt.plot(e, history.history['val_loss'], label='val_loss')
plt.legend(); plt.show()
