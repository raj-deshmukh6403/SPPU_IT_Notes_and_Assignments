# %%
# ===== Stage a: Import necessary packages =====
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, confusion_matrix

# %%
train = pd.read_csv('datasets/cifr/train_data.csv')
test  = pd.read_csv('datasets/cifr/test_data.csv')

# assume last column is 'label'
X_train = train.iloc[:, :-1].to_numpy().astype('float32')  # shape (n, 3072)
y_train = train.iloc[:, -1].to_numpy().astype('int')

X_test  = test.iloc[:, :-1].to_numpy().astype('float32')
y_test  = test.iloc[:, -1].to_numpy().astype('int')

# normalize pixels to [0,1]
X_train /= 255.0
X_test  /= 255.0

# one-hot encode labels
num_classes = len(np.unique(y_train))
y_train_cat = to_categorical(y_train, num_classes)
y_test_cat  = to_categorical(y_test, num_classes)

print("Shapes:", X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# Shapes: (50000, 3072) (50000,) (10000, 3072) (10000,)

# %%
input_dim = X_train.shape[1]
opt = SGD(learning_rate=0.01, momentum=0.9)
#opt = Adam(learning_rate=1e-3)

model = Sequential([
    Input(shape=(input_dim,)),
    Dense(1024, activation='relu'),
    Dropout(0.4),
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 1024)                │       3,146,752 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         524,800 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 512)                 │               0 │
# ...

# %%
# ===== Stage d: Train the model =====
epochs = 11
batch_size = 128

history = model.fit(
    X_train, y_train_cat,
    validation_data=(X_test, y_test_cat),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2
)
# Out:
# Epoch 1/11
# 391/391 - 19s - 49ms/step - accuracy: 0.2891 - loss: 1.9589 - val_accuracy: 0.3646 - val_loss: 1.7873
# Epoch 2/11
# 391/391 - 16s - 41ms/step - accuracy: 0.3485 - loss: 1.8134 - val_accuracy: 0.4028 - val_loss: 1.7000
# Epoch 3/11
# 391/391 - 15s - 40ms/step - accuracy: 0.3655 - loss: 1.7608 - val_accuracy: 0.4114 - val_loss: 1.6630
# Epoch 4/11
# 391/391 - 16s - 40ms/step - accuracy: 0.3796 - loss: 1.7369 - val_accuracy: 0.4215 - val_loss: 1.6228
# Epoch 5/11
# 391/391 - 16s - 40ms/step - accuracy: 0.3932 - loss: 1.6967 - val_accuracy: 0.4345 - val_loss: 1.6059
# Epoch 6/11
# 391/391 - 15s - 40ms/step - accuracy: 0.4044 - loss: 1.6690 - val_accuracy: 0.4414 - val_loss: 1.5954
# Epoch 7/11
# 391/391 - 16s - 40ms/step - accuracy: 0.4101 - loss: 1.6496 - val_accuracy: 0.4563 - val_loss: 1.5412
# Epoch 8/11
# 391/391 - 16s - 40ms/step - accuracy: 0.4202 - loss: 1.6163 - val_accuracy: 0.4570 - val_loss: 1.5209
# Epoch 9/11
# ...

# %%
# ===== Stage e: Evaluate the network =====
loss, acc = model.evaluate(X_test, y_test_cat, verbose=0)
print(f"Test Loss: {loss:.4f}   Test Accuracy: {acc*100:.2f}%\n")

y_pred = np.argmax(model.predict(X_test), axis=1)
print("Classification Report:\n")
print(classification_report(y_test, y_pred, digits=4))

cm = confusion_matrix(y_test, y_pred)
print("Confusion matrix shape:", cm.shape)
# Out:
# Test Loss: 1.4905   Test Accuracy: 47.71%
#
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0     0.6440    0.4160    0.5055      1000
#            1     0.5877    0.6230    0.6049      1000
#            2     0.3290    0.3290    0.3290      1000
#            3     0.3673    0.3280    0.3465      1000
#            4     0.3701    0.4930    0.4228      1000
#            5     0.5038    0.1980    0.2843      1000
#            6     0.4368    0.6600    0.5257      1000
#            7     0.5240    0.5560    0.5395      1000
#            8     0.5647    0.6850    0.6191      1000
#            9     0.5421    0.4830    0.5108      1000
#
#     accuracy                         0.4771     10000
#    macro avg     0.4870    0.4771    0.4688     10000
# weighted avg     0.4870    0.4771    0.4688     10000
#
# Confusion matrix shape: (10, 10)

# %%
# ===== Stage f: Plot training loss and accuracy =====
plt.style.use("ggplot")
ep = range(len(history.history['loss']))

plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.plot(ep, history.history['loss'], label='train_loss')
plt.plot(ep, history.history['val_loss'], label='val_loss')
plt.title('Loss'); plt.xlabel('Epoch'); plt.legend()

plt.subplot(1,2,2)
plt.plot(ep, history.history['accuracy'], label='train_acc')
plt.plot(ep, history.history['val_accuracy'], label='val_acc')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.legend()

plt.tight_layout(); plt.show()
