# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras import Input, models, layers
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.losses import SparseCategoricalCrossentropy

# %%
train = pd.read_csv('datasets/cifr/train_data.csv')
test  = pd.read_csv('datasets/cifr/test_data.csv')
X_train = train.iloc[:, :-1].to_numpy().reshape(-1,32,32,3)
y_train = train.iloc[:, -1].to_numpy().reshape(-1)
X_test  = test.iloc[:, :-1].to_numpy().reshape(-1,32,32,3)
y_test  = test.iloc[:, -1].to_numpy().reshape(-1)

X_train = X_train.astype("float32") / 255.0
X_test  = X_test.astype("float32") / 255.0
y_train = y_train.reshape(-1)
y_test  = y_test.reshape(-1)

# %%
print("Shapes:", X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# Shapes: (50000, 32, 32, 3) (50000,) (10000, 32, 32, 3) (10000,)

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
plt.figure(figsize=(10, 10))

for i in range(10):
  plt.subplot(5, 5, i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(X_train[i])
  plt.xlabel(class_names[train_labels[i][0]])

plt.show()

# %%
model = models.Sequential([
    Input(shape=(32,32,3)),
    layers.Conv2D(32, (3,3), activation="relu", padding="same"),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation="relu", padding="same"),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, (3,3), activation="relu", padding="same"),
    layers.Flatten(),
    layers.Dense(64, activation="relu"),
    layers.Dense(10, activation="softmax")
])

model.compile(
    optimizer=SGD(learning_rate=0.01, momentum=0.9),
    loss=SparseCategoricalCrossentropy(),
    metrics=["accuracy"]
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 32, 32, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 16, 16, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 16, 16, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 8, 8, 64)            │               0 │
# ...

# %%
epochs = 11
batch_size = 128

h = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=epochs, batch_size=batch_size, verbose=2
)
# Out:
# Epoch 1/11
# 391/391 - 34s - 86ms/step - accuracy: 0.3389 - loss: 1.8261 - val_accuracy: 0.4785 - val_loss: 1.4506
# Epoch 2/11
# 391/391 - 29s - 75ms/step - accuracy: 0.5051 - loss: 1.3829 - val_accuracy: 0.5686 - val_loss: 1.2051
# Epoch 3/11
# 391/391 - 29s - 74ms/step - accuracy: 0.5847 - loss: 1.1744 - val_accuracy: 0.6117 - val_loss: 1.0951
# Epoch 4/11
# 391/391 - 29s - 74ms/step - accuracy: 0.6407 - loss: 1.0202 - val_accuracy: 0.6314 - val_loss: 1.0304
# Epoch 5/11
# 391/391 - 29s - 75ms/step - accuracy: 0.6855 - loss: 0.9042 - val_accuracy: 0.6524 - val_loss: 0.9796
# Epoch 6/11
# 391/391 - 30s - 76ms/step - accuracy: 0.7159 - loss: 0.8135 - val_accuracy: 0.6820 - val_loss: 0.9216
# Epoch 7/11
# 391/391 - 28s - 71ms/step - accuracy: 0.7453 - loss: 0.7349 - val_accuracy: 0.7018 - val_loss: 0.8601
# Epoch 8/11
# 391/391 - 28s - 72ms/step - accuracy: 0.7657 - loss: 0.6730 - val_accuracy: 0.7040 - val_loss: 0.8666
# Epoch 9/11
# ...

# %%
loss_f, acc_f = model.evaluate(X_test, y_test, verbose=0)
print(f"Friend-model Test Loss: {loss_f:.4f}, Test Acc: {acc_f*100:.4f}%")

y_pred_f = model.predict(X_test).argmax(axis=1)
print(classification_report(y_test, y_pred_f, digits=4))
cm_f = confusion_matrix(y_test, y_pred_f)
plt.figure(figsize=(6,5)); plt.title("Model Confusion (counts)"); plt.imshow(cm_f, cmap="Blues"); plt.colorbar()
plt.xlabel("Pred"); plt.ylabel("True"); plt.show()
# Out:
# Friend-model Test Loss: 0.9005, Test Acc: 71.2200%
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step
#               precision    recall  f1-score   support
#
#            0     0.7549    0.7670    0.7609      1000
#            1     0.8112    0.8250    0.8180      1000
#            2     0.5529    0.6850    0.6119      1000
#            3     0.5571    0.4930    0.5231      1000
#            4     0.6721    0.6170    0.6434      1000
#            5     0.6239    0.6220    0.6229      1000
#            6     0.8593    0.6960    0.7691      1000
#            7     0.7444    0.7950    0.7689      1000
#            8     0.8547    0.8000    0.8264      1000
#            9     0.7379    0.8220    0.7777      1000
#
#     accuracy                         0.7122     10000
#    macro avg     0.7168    0.7122    0.7122     10000
# weighted avg     0.7168    0.7122    0.7122     10000

# %%
plt.style.use("ggplot")
ep = range(len(h.history["loss"]))

plt.figure(figsize=(12,5))

plt.subplot(1,2,1)
plt.plot(ep, h.history['val_accuracy'], label='friend_val_acc')
plt.title("Validation Accuracy"); plt.legend()

plt.subplot(1,2,2)
plt.plot(ep, h.history['val_loss'], label='friend_val_loss')
plt.title("Validation Loss"); plt.legend()
plt.tight_layout(); plt.show()
